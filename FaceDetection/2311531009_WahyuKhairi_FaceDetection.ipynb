# %% [markdown]
# <a href="https://colab.research.google.com/github/WahyuKhairi06/2311531009_Wahyu-Khairi_ImageProcessing/blob/main/FaceDetection/2311531009_WahyuKhairi_FaceDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install Library**

# %%
# !pip install opencv-python matplotlib

import cv2
import matplotlib.pyplot as plt
from google.colab import files

# %% [markdown]
# upload gambar

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e12e0309-5a0f-45a1-84e1-9c301aa968e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e12e0309-5a0f-45a1-84e1-9c301aa968e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Face Detection

# %%
# LOAD HAAR CASCADE
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades +
    'haarcascade_frontalface_default.xml'
)

# LOAD IMAGE
image_path = '3.jpeg'
img = cv2.imread(image_path)
if img is None:
    raise ValueError("Gambar tidak ditemukan!")

# RESIZE IMAGE
img = cv2.resize(img, (800, 600))

# DISPLAY IMAGE
plt.figure(figsize=(8, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Image Originally')
plt.axis('off')
plt.show()

# %%
# CONVERT TO GRAYSCALE

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(8, 8))
plt.imshow(gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %%
# FACE DETECTION
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(40, 40)
)
# DRAW BOUNDING BOX

for (x, y, w, h) in faces:
    cv2.rectangle(
        img,
        (x, y),
        (x+w, y+h),
        (0, 255, 0),
        3
    )

# %%
# DISPLAY RESULT

plt.figure(figsize=(10,10))

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

plt.title(f'Face Detection | Total Faces: {len(faces)}')

plt.axis('off')

plt.show()

# SAVE OUTPUT
cv2.imwrite('hasil_deteksi.jpg', img)

print(f'Jumlah wajah terdeteksi: {len(faces)}')
print('Output berhasil disimpan.')
# Out:
# Jumlah wajah terdeteksi: 10
# Output berhasil disimpan.
